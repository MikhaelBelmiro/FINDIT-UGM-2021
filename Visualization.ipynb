# %%
import pandas as pd

import seaborn as sn
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
train = pd.read_csv('public-train.csv',delimiter='|')
train
# Out:
#        author_id                                        description  \
# 0     author2106  Just after the Second World War, in the small ...
# 1     author1018  Blame it on Hawaii’s rainbows, sparkling beach...
# 2     author1087  The Pulitzer Prize–winning, bestselling author...
# 3     author1295  THINGS ARE ABOUT TO GET SERIOUS FOR HARRY DRES...
# 4     author2622  The Romanovs were the most successful dynasty ...
# ...          ...                                                ...
# 3545  author1144  How much is too much to love? Travis Maddox le...
# 3546  author2852  Magneto and Professor X. Superman and Lex Luth...
# 3547  author1309  Following the launch of her #1 New York Times ...
# 3548  author1816  Bachelors, beware. For those who keep secrets ...
# 3549  author0882  In the thrilling, nerve-wracking finale of Eze...
#
#           bookformat       bookedition  pages published_date publisher_id  \
# 0          Hardcover               NaN  309.0            NaN          NaN
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3550 entries, 0 to 3549
# Data columns (total 39 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   author_id       3540 non-null   object
#  1   description     3512 non-null   object
#  2   bookformat      3537 non-null   object
#  3   bookedition     231 non-null    object
#  4   pages           3451 non-null   float64
#  5   published_date  568 non-null    object
#  6   publisher_id    568 non-null    object
#  7   reading_age     126 non-null    object
#  8   lexile_measure  88 non-null     object
#  9   grade_level     100 non-null    object
#  10  weight          519 non-null    float64
#  11  rating_value_0  3540 non-null   float64
#  12  rating_value_1  553 non-null    float64
#  13  rating_count_0  3550 non-null   int64
#  14  rating_count_1  3550 non-null   int64
#  15  dimension_0     512 non-null    float64
#  16  dimension_1     512 non-null    float64
# ...

# %%
for i, column in enumerate(train.columns):
    if i == 1:
        continue
    print(f'Unique values dari {column} adalah:')
    print(train[column].unique())
    print()
# Out:
# Unique values dari author_id adalah:
# ['author2106' 'author1018' 'author1087' ... 'author1288' 'author1816'
#  'author0882']
#
# Unique values dari bookformat adalah:
# ['Hardcover' 'Paperback' 'Kindle Edition' 'Mass Market Paperback' 'ebook'
#  'paperback' nan 'Unknown Binding' 'Library Binding' 'Nook' 'Board Book'
#  'Spiral-bound' 'Comics' 'Trade Paperback']
#
# Unique values dari bookedition adalah:
# [nan 'First Edition' 'First Scribner Hardcover Edition' 'First'
#  'English edition' 'First US Edition' 'US' 'First Edition (US)'
#  'First U.S. Edition 2020' '1st Edition' 'First Edition (U.S.)'
#  '1st Edition, USA' '1st edition' 'Canadian' 'Boxed Set' 'Trade'
#  'International Edition' '2' 'First North American Edition'
#  '1st US edition' 'Large Print' '1 edition' 'Hyperion, First Edition'
#  'Deluxe Edition' 'First Printing' 'Deckle Edge' 'Simon Pulse'
#  'First Simon & Schuster hardcover edition September 2018'
# ...

# %%
fig, size = plt.subplots(1,1, figsize=(16,16))
sn.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, size = plt.subplots(1,1, figsize=(16,16))
sn.heatmap(train.corr('spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %%
sn.pairplot(train)
